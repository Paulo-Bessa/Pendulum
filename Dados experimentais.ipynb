# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd

# %%
dat1 = pd.read_csv("Pendulum data/5v_10oct2022_00_data.csv")

# %%
dat1.head()
# Out:
#    Time (s) Run #1  Angle (rad) Run #1  Angular Velocity (rad/s) Run #1  \
# 0            0.000               0.017                              NaN
# 1            0.025               0.087                            2.793
# 2            0.050               0.157                            3.258
# 3            0.075               0.244                            3.723
# 4            0.100               0.349                            4.072
#
#    Angular Acceleration (rad/s²) Run #1  Position (m) Run #1  \
# 0                                   NaN             0.000417
# 1                                   NaN             0.002100
# 2                                18.617             0.003700
# 3                                15.514             0.005800
# 4                                12.411             0.008300
#
#    Velocity (m/s) Run #1  Acceleration (m/s²) Run #1
# 0                    NaN                         NaN
# 1                  0.067                         NaN
# ...

# %%
angle1 = dat1['Angle (rad) Run #1'].values
ang_vel1 = dat1['Angular Velocity (rad/s) Run #1'].values

# %%
plt.plot(angle1,ang_vel1)

# %%
dat2 = pd.read_csv("Pendulum data/5v_10oct2022_01_data.csv")

angle2 = dat2['Angle (rad) Run #1'].values
ang_vel2 = dat2['Angular Velocity (rad/s) Run #1'].values

plt.plot(angle2,ang_vel2)

# %%
dat3 = pd.read_csv("Pendulum data/5v_10oct2022_02_data.csv")

# %%
dat3.head()
# Out:
#      Date and Time Run #1  Time (s) Run #1  \
# 0  10/24/2022 12:02:29 pm             0.00
# 1  10/24/2022 12:02:29 pm             0.01
# 2  10/24/2022 12:02:29 pm             0.02
# 3  10/24/2022 12:02:29 pm             0.03
# 4  10/24/2022 12:02:29 pm             0.04
#
#    Counts/sample (counts/sample) Run #1  Angle, Ch 1+2 (rad) Run #1  \
# 0                                     1                       0.017
# 1                                     1                       0.035
# 2                                     2                       0.070
# 3                                     2                       0.105
# 4                                     2                       0.140
#
#    Angular Velocity (rad/s) Run #1  \
# 0                              NaN
# 1                            2.618
# 2                            3.200
# 3                            3.200
# 4                            2.909
#
# ...

# %%
time3 = dat3['Time (s) Run #1'].values
angle3 = dat3['Angle, Ch 1+2 (rad) Run #1'].values
ang_vel3 = dat3['Angular Velocity (rad/s) Run #1'].values

plt.plot(angle3,ang_vel3)

# %%
angle3
# Out:
# array([1.7000e-02, 3.5000e-02, 7.0000e-02, ..., 6.8993e+01, 6.9063e+01,
#        6.9132e+01])

# %%
time3
# Out:
# array([0.000e+00, 1.000e-02, 2.000e-02, ..., 9.718e+01, 9.719e+01,
#        9.720e+01])

# %%
np.size(angle3)
# Out:
# 9721

# %%
for i in range(9721):

# %%
plt.plot(time3,angle3)
